# %%
def gauss(n):
    return (n*(n+1))/2
gauss(100)==sum(range(101))
# Out:
# True

# %% [markdown]
# # (Header 1, "My Jupyter Notebook on IBM Watson Studio")

# %% [markdown]
# <b>Marzena Pugo</b>

# %% [markdown]
# Transport and Customs Coordinator

# %% [markdown]
# _I am interested in data science because allows me to try various ideas using scientific methods_

# %% [markdown]
# ### (Header 3, we are using a sum function)

# %%
1+1
# Out:
# 2

# %% [markdown]
# ---

# %% [markdown]
# "---"

# %% [markdown]
# <ul>
# <li>banana</li>
# <li>orange</li>
# <li>apple</li>
# </ul>

# %% [markdown]
# <ol>
# <li>banana</li>
# <li>orange</li>
# <li>apple</li>
# </ol>

# %% [markdown]
# __[link to the Guardian](https://www.theguardian.com/uk)__
